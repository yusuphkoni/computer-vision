# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('dsu2.jpg')
rows,cols,ch = img.shape

# %%
pts1 = np.float32([[178,502],[821,511],[179,238],[822,220]])
pts2 = np.float32([[200,500],[800,500],[200,200],[800,200]])

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)

# %%
dst = cv2.warpPerspective(img,M,(1000,1000))

# %%
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu3.jpg')
rows,cols,ch = img.shape

# %%
pts1 = np.float32([[118,497],[706,538],[108,224],[702,161]])
pts2 = np.float32([[100,500],[700,500],[100,200],[700,200]])

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)

# %%
dst = cv2.warpPerspective(img,M,(1000,1000))

# %%
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu4.jpg')
rows,cols,ch = img.shape

# %%
pts1 = np.float32([[239,457],[565,494],[238,268],[567,231]])
pts2 = np.float32([[200,400],[600,400],[200,200],[600,200]])

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)

# %%
dst = cv2.warpPerspective(img,M,(1000,1000))

# %%
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu5.jpg')
rows,cols,ch = img.shape

# %%
pts1 = np.float32([[587,548],[763,538],[579,338],[752,376]])
pts2 = np.float32([[500,500],[700,500],[500,300],[700,300]])

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)

# %%
dst = cv2.warpPerspective(img,M,(1000,1000))

# %%
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu6.jpg')
rows,cols,ch = img.shape

# %%
pts1 = np.float32([[440,575],[702,536],[433,330],[648,350]])
pts2 = np.float32([[400,500],[700,500],[400,300],[600,300]])

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)

# %%
dst = cv2.warpPerspective(img,M,(1000,1000))

# %%
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu7.jpg')
rows,cols,ch = img.shape

# %%
pts1 = np.float32([[287,527],[533,542],[292,407],[536,410]])
pts2 = np.float32([[300,500],[500,500],[300,400],[500,400]])

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)

# %%
dst = cv2.warpPerspective(img,M,(1000,1000))

# %%
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu8.jpg')
rows,cols,ch = img.shape

# %%
pts1 = np.float32([[166,584],[494,595],[175,439],[496,443]])
pts2 = np.float32([[200,600],[500,600],[200,400],[500,400]])

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)

# %%
dst = cv2.warpPerspective(img,M,(1000,1000))

# %%
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu9.jpg')
rows,cols,ch = img.shape

# %%
pts1 = np.float32([[397,606],[640,576],[394,212],[651,215]])
pts2 = np.float32([[400,600],[600,600],[400,200],[600,200]])

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)

# %%
dst = cv2.warpPerspective(img,M,(1000,1000))

# %%
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
