# %%
from PIL import Image
from pylab import *
# import matplotlib.pyplot as pl
# read image to array
im = array(Image.open('C:/Users/cnsl/Documents/COMPUTER VISION/ch12_notebook/best (2).jpg'))
# plot the image
imshow(im)
# some points
x = [100,100,1300,1300]
y = [200,500,200,500]
# plot the points with red star-markers
plot(x,y,'r*')
# line plot connecting the first two points
plot(x[:2],y[:2])
# add title and show the plot
title('Plotting: "best (1).jpg"')
show()
#plot(x,y) # default blue solid line
#plot(x,y,’r*’) # red star-markers
#plot(x,y,’go-’) # green line with circle-markers
#plot(x,y,’ks:’) # black dotted line with square-markers

# %%
# read image to array
im = array(Image.open('C:/Users/cnsl/Documents/COMPUTER VISION/ch12_notebook/best (2).jpg').convert('L'))
# create a new figure
figure()
# don’t use colors
gray()
imshow(im)
figure()
# show contours with origin upper left corner
contour(im, origin='image')
axis('equal')
axis('off')
show()

# %%
figure()
hist(im.flatten(),128)
show()

# %%
figure()
imshow(im)
print("Please click 3 points")
#x = ginput(3)
#print("you clicked:",x)
show()
# Out:
# Please click 3 points
